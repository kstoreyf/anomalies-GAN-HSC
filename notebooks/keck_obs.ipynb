# %%
import numpy as np
# %matplotlib inline
import os

# %load_ext autoreload
# %autoreload 2

import matplotlib
from matplotlib import pyplot as plt
from matplotlib import pylab
# %config InlineBackend.figure_format = 'retina'
matplotlib.rcParams['figure.dpi'] = 80
textsize = 'x-large'
params = {'legend.fontsize': 'x-large',
          'figure.figsize': (8, 8),
         'axes.labelsize': textsize,
         'axes.titlesize': textsize,
         'xtick.labelsize': textsize,
         'ytick.labelsize': textsize}
pylab.rcParams.update(params)

from astropy.io import fits
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
#hdul = fits.open('../data/keck_data/bluedot/d1222_0001.fits')
hdula = fits.open('../data/keck_data/bluedot/d1222_0024.fits')

# %%
info = hdula.info()
hdr = hdula[0].header
hdr1 = hdula[1].header
dataa = hdula[1].data
dataa2 = hdula[2].data
# Out:
# Filename: ../data/keck_data/bluedot/d1222_0024.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU     720   ()
#   1  Video_Input_2    1 ImageHDU       360   (2140, 4096)   uint16
#   2  Video_Input_4    1 ImageHDU       360   (2140, 4096)   uint16
#   3  Video_Input_6    1 ImageHDU       360   (2140, 4096)   int16 (rescales to uint16)
#   4  Video_Input_8    1 ImageHDU       360   (2140, 4096)   int16 (rescales to uint16)
#   5  Video_Input_10    1 ImageHDU       360   (2140, 4096)   int16 (rescales to uint16)
#   6  Video_Input_12    1 ImageHDU       360   (2140, 4096)   int16 (rescales to uint16)
#   7  Video_Input_14    1 ImageHDU       360   (2140, 4096)   int16 (rescales to uint16)
#   8  Video_Input_16    1 ImageHDU       360   (2140, 4096)   int16 (rescales to uint16)
#   9  ObjectCat     1 BinTableHDU     55   12R x 12C   [1J, 68A, 1D, 1D, 8A, 1D, 1D, 1E, 6A, 1D, 1E, 20A]
# ...

# %%
dataa.shape
# Out:
# (4096, 2140)

# %%
hdulb = fits.open('../data/keck_data/bluedot/d1222_0025.fits')
datab = hdulb[1].data

# %%
datab2 = hdulb[2].data

# %%
fig = plt.figure(figsize=(8,8))
ax = plt.gca()
plt.imshow(dataa, cmap='Greys_r')

# %%
fig = plt.figure(figsize=(8,8))
ax = plt.gca()
plt.imshow(dataa2, cmap='Greys_r')

# %%
fig = plt.figure(figsize=(8,8))
ax = plt.gca()
plt.imshow(datab, cmap='Greys_r')

# %%
fig = plt.figure(figsize=(8,8))
ax = plt.gca()
plt.imshow(datab2, cmap='Greys_r')

# %%
x = 1000
plt.plot(dataa[:,x])
plt.plot(datab[:,x])

# %%
plt.figure(figsize=(8,4))
ws = np.arange(0, data.shape[1], 100)
print(ws)
colors = plt.cm.rainbow(np.linspace(0, 1, len(ws)))

for i in range(len(ws)): 
    w = ws[i]
    plt.plot(dataa[:,w], color=colors[i])
    
plt.xlim(2200, 4096)
plt.xlabel("wavelength")
plt.ylabel("flux")
# Out:
# [   0  100  200  300  400  500  600  700  800  900 1000 1100 1200 1300
#  1400 1500 1600 1700 1800 1900 2000 2100]
# Text(0, 0.5, 'flux')

# %%
x = 1000
plt.plot(dataa[:,x])
plt.plot(datab[:,x])
plt.xlim(3000, 3200)
# Out:
# (3000, 3200)

# %%
hdul.close()
